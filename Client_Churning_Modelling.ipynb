# %% [markdown]
# ### importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# loading the dataset
data = pd.read_excel("Final_BCG.xlsx")

# %%
data.sample(10)
# Out:
#         Unnamed: 0                                id  \
# 96337        96337  52a7dc941da31bd0f79fc0a5b01ecd50
# 124559      124559  5fa443de7bd82539d38248249677ee86
# 135345      135345  07160b57e8e685de4a0a60e356fffb50
# 107173      107173  e0e4624af640cb4284212752f82d1b29
# 53492        53492  805f818aa0eefcdfb763b0cd3b7206df
# 156641      156641  90a56b191d6a9780cbe0aa25b0c5d9e8
# 84494        84494  f1a6d9f2f6349049bbc4306a94ff6df2
# 116437      116437  9d07e4d3891dc27a40d2ee303cdec1cb
# 117198      117198  c42908cc26ccd8ff758fb4c9af2e0081
# 3073          3073  1c55c6785645c643d564dd59ff96204b
#
#                            channel_sales  contract_dur  durfa_to_ren  \
# 96337   foosdfpfkusacimwkcsosbicdxkicaua            11            10
# 124559  lmkebamcaaclubfxadlmueccxoimlema             3             2
# 135345  foosdfpfkusacimwkcsosbicdxkicaua             4             3
# 107173  foosdfpfkusacimwkcsosbicdxkicaua             5             4
# 53492   foosdfpfkusacimwkcsosbicdxkicaua            11            10
# 156641  foosdfpfkusacimwkcsosbicdxkicaua             5             4
# 84494   lmkebamcaaclubfxadlmueccxoimlema             5             4
# 116437  foosdfpfkusacimwkcsosbicdxkicaua             6             5
# 117198  foosdfpfkusacimwkcsosbicdxkicaua             7             6
# 3073    foosdfpfkusacimwkcsosbicdxkicaua             7             6
#
#         acmod_dur  cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# 96337           0     36329             0             3181            3668.36
# 124559          0    897536        553593            38224               0.00
# 135345          2      1910             0              228             282.70
# 107173          0     13136             0                0            1953.10
# 53492           0     82696             0             5801             512.07
# 156641          3     17811             0             3080            2628.50
# 84494           0   6207104         41532           558120            5036.60
# 116437          5     11305             0                0            1649.06
# 117198          0      2822             0                0             419.93
# 3073            0      7066             0                0            1059.18
#
#         ...  nb_prod_act  net_margin  num_years_antig  \
# 96337   ...            1      402.27               11
# 124559  ...            2        0.00                4
# 135345  ...            1       33.83                4
# 107173  ...            1      183.95                4
# 53492   ...            1       53.36               10
# 156641  ...            2      211.43                4
# 84494   ...            2      393.57                5
# 116437  ...            1      110.03                5
# 117198  ...            1       37.81                6
# 3073    ...            1      103.87                7
#
#                                origin_up  pow_max  price_date  \
# 96337   ldkssxwpmemidmecebumciepifcamkci   19.800  2015-08-01
# 124559  lxidpiddsbxsbosboudacockeimpuepw   75.600  2015-08-01
# 135345  lxidpiddsbxsbosboudacockeimpuepw   13.150  2015-08-01
# 107173  ldkssxwpmemidmecebumciepifcamkci   13.200  2015-06-01
# 53492   ldkssxwpmemidmecebumciepifcamkci   13.200  2015-04-01
# 156641  lxidpiddsbxsbosboudacockeimpuepw   13.000  2015-06-01
# 84494   lxidpiddsbxsbosboudacockeimpuepw   13.856  2015-06-01
# 116437  lxidpiddsbxsbosboudacockeimpuepw   10.392  2015-02-01
# 117198  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.200  2015-07-01
# 3073    ldkssxwpmemidmecebumciepifcamkci   13.200  2015-02-01
#
#        price_mid_peak_var  price_peak_fix  price_mid_peak_fix  churn
# 96337            0.074516       24.437330           16.291555      0
# 124559           0.065432       36.490689            8.367731      0
# 135345           0.000000        0.000000            0.000000      0
# 107173           0.000000        0.000000            0.000000      0
# 53492            0.000000        0.000000            0.000000      0
# 156641           0.000000        0.000000            0.000000      0
# 84494            0.000000        0.000000            0.000000      0
# 116437           0.000000        0.000000            0.000000      0
# 117198           0.000000        0.000000            0.000000      1
# 3073             0.000000        0.000000            0.000000      0
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Data Exploration

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175149 entries, 0 to 175148
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   175149 non-null  int64
#  1   id                           175149 non-null  object
#  2   channel_sales                175149 non-null  object
#  3   contract_dur                 175149 non-null  int64
#  4   durfa_to_ren                 175149 non-null  int64
#  5   acmod_dur                    175149 non-null  int64
#  6   cons_12m                     175149 non-null  int64
#  7   cons_gas_12m                 175149 non-null  int64
#  8   cons_last_month              175149 non-null  int64
#  9   forecast_cons_12m            175149 non-null  float64
#  10  forecast_cons_year           175149 non-null  int64
#  11  forecast_discount_energy     175149 non-null  int64
#  12  forecast_meter_rent_12m      175149 non-null  float64
#  13  change_energy_price_offpeak  175149 non-null  float64
#  14  change_energy_price_peak     175149 non-null  float64
#  15  change_power_price_offpeak   175149 non-null  float64
#  16  has_gas                      175149 non-null  object
#  17  imp_cons                     175149 non-null  float64
#  18  margin_gross_pow_ele         175149 non-null  float64
#  19  margin_net_pow_ele           175149 non-null  float64
#  20  nb_prod_act                  175149 non-null  int64
#  21  net_margin                   175149 non-null  float64
#  22  num_years_antig              175149 non-null  int64
#  23  origin_up                    175149 non-null  object
#  24  pow_max                      175149 non-null  float64
#  25  price_date                   175149 non-null  object
#  26  price_mid_peak_var           175149 non-null  float64
#  27  price_peak_fix               175149 non-null  float64
#  28  price_mid_peak_fix           175149 non-null  float64
#  29  churn                        175149 non-null  int64
# dtypes: float64(13), int64(12), object(5)
# memory usage: 40.1+ MB

# %%
# looking for duplicates in the data
data.duplicated().sum()
# Out:
# 0

# %%
# number of unique variables in object columns
for column in data.select_dtypes("object"):#.drop("id", axis = 1).columns:
    print("*"*40)
    print(f"The number of unique values in the {column} column is: {data[column].nunique()}.\n With the value counts as follows:\n")
    print(f"{data[column].value_counts()}")
    print("*"*40)
# Out:
# ****************************************
# The number of unique values in the id column is: 14606.
#  With the value counts as follows:
#
# 0e8df670a11a4f835b562bcfbafa6144    12
# 3eeca294a2985aaf51c282f9657e3068    12
# 327aac5866baf2bfe6a14c359a515aa7    12
# b641db18102518188d9618d0756547ef    12
# 1b90ee21ac169fd4d14dad0394c8df01    12
#                                     ..
# 9c9d8de40aee618b75f36e9b0f0586b6     9
# 3e459d61dc831e29f8a9a9a59f95efd2     8
# c5dcd5c506e565aaabffa29bc1ec0a37     7
# 15b36e47cf04bf151e3f4438d12672e5     7
# bf89f2d8c1b133a134fd93603cb4c947     7
# Name: id, Length: 14606, dtype: int64
# ****************************************
# ****************************************
# The number of unique values in the channel_sales column is: 7.
#  With the value counts as follows:
#
# foosdfpfkusacimwkcsosbicdxkicaua    125655
# lmkebamcaaclubfxadlmueccxoimlema     22105
# usilxuppasemubllopkaafesmlibmsdf     16486
# ewpakwlliwisiwduibdlfmalxowmwpci     10712
# sddiedcslfslkckwlfkdpoeeailfpeds       131
# epumfxlbckeskwekxbiuasklxalciiuu        36
# fixdbufsefwooaasfcxdxadsiekoceaa        24
# Name: channel_sales, dtype: int64
# ****************************************
# ****************************************
# The number of unique values in the has_gas column is: 2.
#  With the value counts as follows:
#
# f    143364
# t     31785
# Name: has_gas, dtype: int64
# ****************************************
# ****************************************
# The number of unique values in the origin_up column is: 5.
#  With the value counts as follows:
#
# lxidpiddsbxsbosboudacockeimpuepw    85853
# kamkkxfxxuwbdslkwifmmcsiusiuosws    51503
# ldkssxwpmemidmecebumciepifcamkci    37757
# usapbepcfoloekilkwsdiboslwaxobdp       24
# ewxeelcelemmiwuafmddpobolfuxioce       12
# Name: origin_up, dtype: int64
# ****************************************
# ****************************************
# The number of unique values in the price_date column is: 12.
#  With the value counts as follows:
#
# 2015-12-01    14604
# 2015-08-01    14604
# 2015-07-01    14601
# 2015-11-01    14599
# 2015-10-01    14597
# 2015-06-01    14596
# 2015-02-01    14596
# 2015-09-01    14593
# 2015-04-01    14592
# 2015-03-01    14591
# 2015-05-01    14590
# 2015-01-01    14586
# Name: price_date, dtype: int64
# ****************************************

# %% [markdown]
# As each of the object columns contains values less than 15 in iteration, except for the ID column, we will exclude the ID column while encoding the rest of the columns.
#
# For the price_date column we'll  extract a month price column, thus the resulting new data will be in machine readable format.

# %% [markdown]
# ### Data Preprocessing and Feature Engineering

# %%
# creating a copy of the original data
data1 = data.copy()

# %%
# dropping the id column
data1.drop("id", axis = 1, inplace = True)

# %%
# replacing 1 for "t" and 0 for "f" in the has_gas column
data1["has_gas"] = data1["has_gas"].replace({"t": 1, "f": 0})

# %%
# converting the price_date column into month_price
data1["price_date"] = pd.to_datetime(data1["price_date"])

data1["month"] = data1["price_date"].dt.month

# %%
# dropping the price_date column
data1.drop("price_date", axis = 1, inplace = True)

# %%
data1.sample(5)
# Out:
#        Unnamed: 0                     channel_sales  contract_dur  \
# 60215       60215  foosdfpfkusacimwkcsosbicdxkicaua             5
# 72955       72955  foosdfpfkusacimwkcsosbicdxkicaua             7
# 82043       82043  usilxuppasemubllopkaafesmlibmsdf             4
# 47366       47366  foosdfpfkusacimwkcsosbicdxkicaua             8
# 43771       43771  foosdfpfkusacimwkcsosbicdxkicaua            12
#
#        durfa_to_ren  acmod_dur  cons_12m  cons_gas_12m  cons_last_month  \
# 60215             4          2     36775         47130             1885
# 72955             6          0      4485             0              341
# 82043             3          2     23455             0             1739
# 47366             7          0         0             0                0
# 43771            11         10     78842             0             4571
#
#        forecast_cons_12m  forecast_cons_year  ...  nb_prod_act  net_margin  \
# 60215            3852.54                1885  ...            2      547.99
# 72955             460.13                 341  ...            1       50.80
# 82043            2276.48                1739  ...            1      286.08
# 47366               0.00                   0  ...            1        0.00
# 43771            2626.50                   0  ...            1      192.89
#
#        num_years_antig                         origin_up  pow_max  \
# 60215                4  lxidpiddsbxsbosboudacockeimpuepw   31.180
# 72955                6  ldkssxwpmemidmecebumciepifcamkci   26.400
# 82043                4  ldkssxwpmemidmecebumciepifcamkci   17.321
# 47366                8  ldkssxwpmemidmecebumciepifcamkci   15.000
# 43771               11  ldkssxwpmemidmecebumciepifcamkci   13.200
#
#        price_mid_peak_var  price_peak_fix  price_mid_peak_fix  churn  month
# 60215            0.072612       24.437330           16.291555      0      3
# 72955            0.071536       24.339581           16.226389      0      6
# 82043            0.072394       24.437330           16.291555      1      2
# 47366            0.065678       36.490689            8.367731      0      9
# 43771            0.000000        0.000000            0.000000      0     11
#
# [5 rows x 29 columns]

# %%
# summary satatistics for int and float columns
data1.describe()
# Out:
#           Unnamed: 0   contract_dur   durfa_to_ren      acmod_dur  \
# count  175149.000000  175149.000000  175149.000000  175149.000000
# mean    87574.000000       5.318483       4.383319       1.594345
# std     50561.305487       1.695892       1.672747       2.017220
# min         0.000000       2.000000       0.000000       0.000000
# 25%     43787.000000       4.000000       3.000000       0.000000
# 50%     87574.000000       5.000000       4.000000       0.000000
# 75%    131361.000000       6.000000       5.000000       3.000000
# max    175148.000000      13.000000      12.000000      11.000000
#
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.751490e+05  1.751490e+05    175149.000000      175149.000000
# mean   1.592606e+05  2.808072e+04     16095.518404        1868.343884
# std    5.735413e+05  1.629400e+05     64376.741908        2387.560169
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674000e+03  0.000000e+00         0.000000         494.980000
# 50%    1.411500e+04  0.000000e+00       792.000000        1112.610000
# 75%    4.076300e+04  0.000000e+00      3383.000000        2400.350000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  ...  margin_net_pow_ele  \
# count       175149.000000             175149.000000  ...       175149.000000
# mean          1399.782380                  0.967028  ...           24.564223
# std           3248.331276                  5.109025  ...           20.233588
# min              0.000000                  0.000000  ...            0.000000
# 25%              0.000000                  0.000000  ...           14.280000
# 50%            314.000000                  0.000000  ...           21.640000
# 75%           1745.000000                  0.000000  ...           29.880000
# max         175375.000000                 30.000000  ...          374.640000
#
#         nb_prod_act     net_margin  num_years_antig        pow_max  \
# count  175149.00000  175149.000000    175149.000000  175149.000000
# mean        1.29230     189.245305         4.998276      18.134896
# std         0.70978     311.846765         1.611801      13.535809
# min         1.00000       0.000000         1.000000       3.300000
# 25%         1.00000      50.710000         4.000000      12.500000
# 50%         1.00000     112.500000         5.000000      13.856000
# 75%         1.00000     243.000000         6.000000      19.180000
# max        32.00000   24570.650000        13.000000     320.000000
#
#        price_mid_peak_var  price_peak_fix  price_mid_peak_fix          churn  \
# count       175149.000000   175149.000000       175149.000000  175149.000000
# mean             0.028270        9.458953            6.096434       0.097077
# std              0.036065       12.133202            7.822250       0.296064
# min              0.000000        0.000000            0.000000       0.000000
# 25%              0.000000        0.000000            0.000000       0.000000
# 50%              0.000000        0.000000            0.000000       0.000000
# 75%              0.072900       24.339581           16.226389       0.000000
# max              0.114102       36.490689           17.458221       1.000000
#
#                month
# count  175149.000000
# mean        6.500911
# std         3.452020
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# #### Label Encoding

# %%
# Label Encoder Library importation
from sklearn.preprocessing import LabelEncoder

# %%
# encoding the remaining object columns
encoder = LabelEncoder()

for column in data1.select_dtypes("object").columns:
    data1[column] = encoder.fit_transform(data1[column])

# %%
data1.sample(6).T
# Out:
#                                     173066         126941         144187  \
# contract_dur                      8.000000       5.000000       4.000000
# channel_sales                     3.000000       3.000000       3.000000
# durfa_to_ren                      6.000000       4.000000       3.000000
# column_x                     173066.000000  126941.000000  144187.000000
# acmod_dur                         7.000000       3.000000       2.000000
# cons_12m                      30510.000000   74898.000000    6372.000000
# cons_gas_12m                      0.000000  409715.000000       0.000000
# cons_last_month                4499.000000    6556.000000       0.000000
# forecast_cons_12m              2615.220000    1616.160000     440.990000
# forecast_cons_year             4499.000000    1567.000000       0.000000
# forecast_discount_energy          0.000000       0.000000       0.000000
# forecast_meter_rent_12m         140.150000      14.860000      17.050000
# change_energy_price_offpeak      -0.003113      -0.001488       0.001062
# change_energy_price_peak          0.000387       0.000000       0.000000
# change_power_price_offpeak       18.330073      -0.863668      -1.860668
# has_gas                           0.000000       1.000000       0.000000
# month                             5.000000      11.000000       9.000000
# imp_cons                        426.900000     225.850000       0.000000
# margin_gross_pow_ele              3.810000      12.000000      26.040000
# margin_net_pow_ele                3.810000      12.000000      26.040000
# nb_prod_act                       1.000000       2.000000       1.000000
# net_margin                      254.590000     117.470000      46.260000
# num_years_antig                   7.000000       4.000000       3.000000
# origin_up                         2.000000       3.000000       3.000000
# pow_max                          20.000000      10.520000      10.392000
# price_mid_peak_var                0.070730       0.000000       0.000000
# price_peak_fix                   36.344726       0.000000       0.000000
# price_mid_peak_fix                8.334260       0.000000       0.000000
# churn                             0.000000       0.000000       1.000000
#
#                                    27742        4088           83693
# contract_dur                     3.000000     2.000000       7.000000
# channel_sales                    1.000000     3.000000       3.000000
# durfa_to_ren                     2.000000     2.000000       6.000000
# column_x                     27742.000000  4088.000000   83693.000000
# acmod_dur                        2.000000     2.000000       5.000000
# cons_12m                     45880.000000  5071.000000  367281.000000
# cons_gas_12m                     0.000000     0.000000       0.000000
# cons_last_month               3841.000000   359.000000   32896.000000
# forecast_cons_12m             1708.200000   764.500000    3219.330000
# forecast_cons_year            3841.000000   359.000000    2748.000000
# forecast_discount_energy         0.000000     0.000000       0.000000
# forecast_meter_rent_12m        155.320000    19.170000     142.840000
# change_energy_price_offpeak      0.010713     0.008170       0.006498
# change_energy_price_peak         0.004384     0.000000       0.003455
# change_power_price_offpeak       0.122184    -0.044447      -0.040728
# has_gas                          0.000000     0.000000       0.000000
# month                            1.000000     1.000000       9.000000
# imp_cons                       403.000000    52.410000     255.700000
# margin_gross_pow_ele            69.960000    33.120000       1.320000
# margin_net_pow_ele              69.960000    33.120000       1.320000
# nb_prod_act                      2.000000     1.000000       1.000000
# net_margin                      99.880000    72.290000     285.160000
# num_years_antig                  3.000000     3.000000       6.000000
# origin_up                        2.000000     3.000000       3.000000
# pow_max                         20.000000    13.200000      29.700000
# price_mid_peak_var               0.072394     0.000000       0.072268
# price_peak_fix                  24.437330     0.000000      24.339578
# price_mid_peak_fix              16.291555     0.000000      16.226383
# churn                            0.000000     0.000000       0.000000

# %%
data1.columns
# Out:
# Index(['contract_dur', 'channel_sales', 'durfa_to_ren', 'column_x',
#        'acmod_dur', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'change_energy_price_offpeak',
#        'change_energy_price_peak', 'change_power_price_offpeak', 'has_gas',
#        'month', 'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele',
#        'nb_prod_act', 'net_margin', 'num_years_antig', 'origin_up', 'pow_max',
#        'price_mid_peak_var', 'price_peak_fix', 'price_mid_peak_fix', 'churn'],
#       dtype='object')

# %%
# renaming the unnamed column 
data1.rename(columns={'Unnamed: 0': 'column_x'}, inplace=True)

# %% [markdown]
# #### Rearranging the columns

# %%
new_column_order = ['contract_dur', 'channel_sales', 'durfa_to_ren',  'column_x', 
       'acmod_dur', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
       'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
       'forecast_meter_rent_12m', 'change_energy_price_offpeak',
       'change_energy_price_peak', 'change_power_price_offpeak', 'has_gas', 'month',
       'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
       'net_margin', 'num_years_antig', 'origin_up', 'pow_max',
       'price_mid_peak_var', 'price_peak_fix', 'price_mid_peak_fix', 'churn']

data1 = data1[new_column_order]

# %% [markdown]
# ### Outlier Removal

# %% [markdown]
# #### Visualizing the effect of outliers using boxplot

# %%
for column in data1.drop(['channel_sales','has_gas', 'month','origin_up', 'churn'], axis = 1).columns:
    plt.figure(figsize = (10,8))
    sns.boxplot(x= column , color = "r", data = data1)
    plt.title(f"The Boxplot of the {column}")
    plt.show()

# %%
def outlier_remover(data):
    data_new = data.copy()
    
    for column in data.drop(['channel_sales', 'has_gas', 'month', 'origin_up', 'churn'], axis=1).columns:
        Q1 = data_new[column].quantile(0.25)
        Q3 = data_new[column].quantile(0.75)
        IQR = Q3 - Q1
        multiplier = 1.5
        LF = Q1 - (IQR * multiplier)
        UF = Q3 + (IQR * multiplier)
        outliers = data_new[(data_new[column] > UF) | (data_new[column] < LF)]
        data_new = data_new[~data_new.index.isin(outliers.index)]
    
    return data_new

# %%
data2 =  outlier_remover(data1)

data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45684 entries, 12 to 175136
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   contract_dur                 45684 non-null  int64
#  1   channel_sales                45684 non-null  int32
#  2   durfa_to_ren                 45684 non-null  int64
#  3   column_x                     45684 non-null  int64
#  4   acmod_dur                    45684 non-null  int64
#  5   cons_12m                     45684 non-null  int64
#  6   cons_gas_12m                 45684 non-null  int64
#  7   cons_last_month              45684 non-null  int64
#  8   forecast_cons_12m            45684 non-null  float64
#  9   forecast_cons_year           45684 non-null  int64
#  10  forecast_discount_energy     45684 non-null  int64
#  11  forecast_meter_rent_12m      45684 non-null  float64
#  12  change_energy_price_offpeak  45684 non-null  float64
#  13  change_energy_price_peak     45684 non-null  float64
#  14  change_power_price_offpeak   45684 non-null  float64
#  15  has_gas                      45684 non-null  int64
#  16  month                        45684 non-null  int64
#  17  imp_cons                     45684 non-null  float64
#  18  margin_gross_pow_ele         45684 non-null  float64
#  19  margin_net_pow_ele           45684 non-null  float64
#  20  nb_prod_act                  45684 non-null  int64
#  21  net_margin                   45684 non-null  float64
#  22  num_years_antig              45684 non-null  int64
#  23  origin_up                    45684 non-null  int32
#  24  pow_max                      45684 non-null  float64
#  25  price_mid_peak_var           45684 non-null  float64
#  26  price_peak_fix               45684 non-null  float64
#  27  price_mid_peak_fix           45684 non-null  float64
#  28  churn                        45684 non-null  int64
# dtypes: float64(13), int32(2), int64(14)
# memory usage: 10.1 MB

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175149 entries, 0 to 175148
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   contract_dur                 175149 non-null  int64
#  1   channel_sales                175149 non-null  int32
#  2   durfa_to_ren                 175149 non-null  int64
#  3   column_x                     175149 non-null  int64
#  4   acmod_dur                    175149 non-null  int64
#  5   cons_12m                     175149 non-null  int64
#  6   cons_gas_12m                 175149 non-null  int64
#  7   cons_last_month              175149 non-null  int64
#  8   forecast_cons_12m            175149 non-null  float64
#  9   forecast_cons_year           175149 non-null  int64
#  10  forecast_discount_energy     175149 non-null  int64
#  11  forecast_meter_rent_12m      175149 non-null  float64
#  12  change_energy_price_offpeak  175149 non-null  float64
#  13  change_energy_price_peak     175149 non-null  float64
#  14  change_power_price_offpeak   175149 non-null  float64
#  15  has_gas                      175149 non-null  int64
#  16  month                        175149 non-null  int64
#  17  imp_cons                     175149 non-null  float64
#  18  margin_gross_pow_ele         175149 non-null  float64
#  19  margin_net_pow_ele           175149 non-null  float64
#  20  nb_prod_act                  175149 non-null  int64
#  21  net_margin                   175149 non-null  float64
#  22  num_years_antig              175149 non-null  int64
#  23  origin_up                    175149 non-null  int32
#  24  pow_max                      175149 non-null  float64
#  25  price_mid_peak_var           175149 non-null  float64
#  26  price_peak_fix               175149 non-null  float64
#  27  price_mid_peak_fix           175149 non-null  float64
#  28  churn                        175149 non-null  int64
# dtypes: float64(13), int32(2), int64(14)
# memory usage: 37.4 MB
